# %% [markdown]
# <a href="https://colab.research.google.com/github/ToddAbrahamII/IT_262_Code/blob/main/BurndownChart_ToddA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %cd /content/drive/MyDrive/
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive

# %%
myData=pd.read_csv('/content/drive/My Drive/BDU.csv')

# %%
myData.shape
myData.head(2)
# Out:
#         dates  scope  ideal  actual  Cideal  Cactual  Lideal  Lactual
# 0  10/12/2021     36      0       0       0        0      36       36
# 1  10/13/2021     36      1       0       1        0      35       36

# %%
fig, (ax1,ax2)= plt.subplots(1,2, figsize=(30,8))

ax1.set_xlabel('days')
ax2.set_xlabel('days')

ax1.plot(myData.Cideal, color='pink', label='work completed - ideal')
ax3=ax1.twinx()
ax3.plot(myData.Cactual, color='green', label= 'work completed - actual')

ax2.plot(myData.Lideal, color ='pink', label='work to be done - ideal')
ax4 =ax2.twinx()
ax4.plot(myData.Lactual, color='green', label='work to be done - actual')
ax1.set_title('Burn Up')
ax2.set_title('Burn Down')

h1, l1 = ax1.get_legend_handles_labels()
h3, l3 = ax3.get_legend_handles_labels()
ax3.legend(h1+h3, l1+l3, loc=2, prop={'size': 15})
h2, l2 = ax2.get_legend_handles_labels()
h4, l4 = ax4.get_legend_handles_labels()
ax4.legend(h1+h3,l1+l3, loc=2, prop={'size': 15})


plt.show()
